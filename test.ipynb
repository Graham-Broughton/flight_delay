# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, RobustScaler, OrdinalEncoder
from sklearn.linear_model import LinearRegression, SGDClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import f_regression, SelectKBest, VarianceThreshold, SelectKBest
import statsmodels.api as sm
from pandas import to_datetime
from pycaret.regression import *
from datetime import datetime
from test_functions import *

# %%
test = pd.read_csv('EDA_and_preprocessing/G_PSQL_data/flights_TEST.txt')

# %%
test['fl_date'] = pd.to_datetime(test['year'].astype(str) + '-' + test['month'].astype(str) + '-' + test['day'].astype(str))

# %%
test = test[test['day'] < 8]

# %%
test = process_times(test)
test = combine_tail_num_avg(dec, test)
test = combine_carriers(dec, test)
test = combine_weekly(dec, test)
test = combine_hourly(dec, test)
test = combine_routes(dec, test)
test = airport_combine_test(dec, test)
test.columns
# Out:
# Index(['year', 'month', 'day', 'op_unique_carrier', 'tail_num',
#        'origin_airport_id', 'dest_airport_id', 'crs_dep_time', 'crs_arr_time',
#        'crs_elapsed_time', 'fl_date', 'dep_hour', 'arr_hour', 'weekday',
#        'month_day', 'tail_arr', 'tail_dep', 'tail_taxi', 'tail_precent_late',
#        'tail_percent_reduce_delay', 'carrier_arr', 'carrier_dep',
#        'carrier_percent_late', 'carrier_taxi_total',
#        'percent_carrier_delay_reduced', 'weekday_arr', 'weekday_dep',
#        'weekday_taxi', 'weekly_percent_late', 'weekly_reduced_delay',
#        'arr_hourly_arr', 'arr_hourly_dep', 'arr_hour_taxi',
#        'arr_hourly_percent_late', 'arr_hourly_percent_reduced_delay',
#        'dep_hourly_arr', 'dep_hourly_dep', 'dep_hourly_taxi',
#        'dep_hourly_percent_late', 'dep_hourly_percent_reduced',
#        'route_arr_mean', 'route_dep_mean', 'carrier_route_arr_mean',
#        'carrier_route_dep_mean', 'carrier_route_air_percent',
#        'tail_route_arr_mean', 'tail_route_dep_mean', 'tail_route_air_ratio',
#        'airport_weekly_hourly_arr', 'airport_weekly_hourly_dep',
#        'airport_arr_hourly_late_percent', 'airport_dep_hourly_late_percent',
#        'airport_taxi_in', 'airport_taxi_out'],
#       dtype='object')

# %%
test = test.drop(columns=['fl_date', 'crs_dep_time', 'crs_arr_time', 'month', 'day', 'year'])

# %%
df = pd.read_csv('EDA_and_preprocessing/G_PSQL_data/test3.csv')

# %%
big = pd.read_csv('EDA_and_preprocessing/G_PSQL_data/random_sample.txt')

# %%
dec = dec[dec['month_day'] > 14]

# %%
from EDA_and_preprocessing.functions import *
dec = remove_outliers(dec)
dec = process_times(dec)
dec = process_binary(dec)
dec = airport_hour_avgs(dec)
dec = tail_num_avg(dec)
dec = process_carriers(dec)
dec = process_hourly(dec)
dec = process_weekly(dec)
dec = process_routes(dec)

# %%
X_test = test.drop(columns=['fl_date', 'op_unique_carrier', 'tail_num', 'origin_airport_id','dest_airport_id', 'crs_dep_time', 'crs_arr_time', 'weekday', 'month_day', 'month', 'day', 'year'])

# %%
X = dec.drop(columns=['fl_date', 'op_unique_carrier', 'tail_num', 'origin_airport_id','dest_airport_id', 'crs_dep_time', 'dep_time', 'dep_delay', 'taxi_out','taxi_in', 'crs_arr_time', 'carrier_route_air_actual', 'carrier_route_air_pred', 'arr_time', 'actual_elapsed_time','weekday', 'month_day','late_binary', 'reduced_delay_flight','taxi_total'])

# %%
X_test = test
cols = X.drop(columns='arr_delay').columns
cols = cols
X_test = X_test[cols]

# %%
from pycaret.regression import *
exp1 = setup(data=X,target='arr_delay', ignore_low_variance=False, combine_rare_levels=True, feature_interaction=False, feature_selection=False, feature_selection_threshold=0.6, feature_ratio=False, polynomial_features=False, remove_outliers=True, remove_multicollinearity=True, transformation=True, fold=4)
# Out:
# <style type="text/css">
# #T_05e70_row29_col1, #T_05e70_row35_col1, #T_05e70_row38_col1, #T_05e70_row40_col1, #T_05e70_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_05e70">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05e70_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_05e70_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05e70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05e70_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_05e70_row0_col1" class="data row0 col1" >6877</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_05e70_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_05e70_row1_col1" class="data row1 col1" >arr_delay</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_05e70_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_05e70_row2_col1" class="data row2 col1" >(345122, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_05e70_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_05e70_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_05e70_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_05e70_row4_col1" class="data row4 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_05e70_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_05e70_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_05e70_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_05e70_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_05e70_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_05e70_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_05e70_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_05e70_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_05e70_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_05e70_row9_col1" class="data row9 col1" >(229506, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_05e70_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_05e70_row10_col1" class="data row10 col1" >(103537, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_05e70_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_05e70_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_05e70_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_05e70_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_05e70_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_05e70_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_05e70_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_05e70_row14_col1" class="data row14 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_05e70_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_05e70_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_05e70_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_05e70_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_05e70_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_05e70_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_05e70_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_05e70_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_05e70_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_05e70_row19_col1" class="data row19 col1" >a6de</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_05e70_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_05e70_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_05e70_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_05e70_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_05e70_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_05e70_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_05e70_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_05e70_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_05e70_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_05e70_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_05e70_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_05e70_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_05e70_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_05e70_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_05e70_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_05e70_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_05e70_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_05e70_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_05e70_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_05e70_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_05e70_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_05e70_row30_col0"

# %%
lightdec = create_model('lightgbm', fold=2)
# Out:
# <style type="text/css">
# #T_cd4af_row2_col0, #T_cd4af_row2_col1, #T_cd4af_row2_col2, #T_cd4af_row2_col3, #T_cd4af_row2_col4, #T_cd4af_row2_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_cd4af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd4af_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_cd4af_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_cd4af_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_cd4af_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_cd4af_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_cd4af_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd4af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd4af_row0_col0" class="data row0 col0" >7.3653</td>
#       <td id="T_cd4af_row0_col1" class="data row0 col1" >165.0666</td>
#       <td id="T_cd4af_row0_col2" class="data row0 col2" >12.8478</td>
#       <td id="T_cd4af_row0_col3" class="data row0 col3" >0.6807</td>
#       <td id="T_cd4af_row0_col4" class="data row0 col4" >0.7888</td>
#       <td id="T_cd4af_row0_col5" class="data row0 col5" >0.7828</td>
#     </tr>
#     <tr>
#       <th id="T_cd4af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd4af_row1_col0" class="data row1 col0" >7.3672</td>
#       <td id="T_cd4af_row1_col1" class="data row1 col1" >165.0132</td>
#       <td id="T_cd4af_row1_col2" class="data row1 col2" >12.8457</td>
#       <td id="T_cd4af_row1_col3" class="data row1 col3" >0.6803</td>
#       <td id="T_cd4af_row1_col4" class="data row1 col4" >0.7921</td>
#       <td id="T_cd4af_row1_col5" class="data row1 col5" >0.7792</td>
#     </tr>
#     <tr>
#       <th id="T_cd4af_level0_row2" class="row_heading level0 row2" >Mean</th>
#       <td id="T_cd4af_row2_col0" class="data row2 col0" >7.3663</td>
#       <td id="T_cd4af_row2_col1" class="data row2 col1" >165.0399</td>
#       <td id="T_cd4af_row2_col2" class="data row2 col2" >12.8468</td>
#       <td id="T_cd4af_row2_col3" class="data row2 col3" >0.6805</td>
#       <td id="T_cd4af_row2_col4" class="data row2 col4" >0.7905</td>
#       <td id="T_cd4af_row2_col5" class="data row2 col5" >0.7810</td>
#     </tr>
#     <tr>
#       <th id="T_cd4af_level0_row3" class="row_heading level0 row3" >Std</th>
#       <td id="T_cd4af_row3_col0" class="data row3 col0" >0.0010</td>
#       <td id="T_cd4af_row3_col1" class="data row3 col1" >0.0267</td>
#       <td id="T_cd4af_row3_col2" class="data row3 col2" >0.0010</td>
#       <td id="T_cd4af_row3_col3" class="data row3 col3" >0.0002</td>
#       <td id="T_cd4af_row3_col4" class="data row3 col4" >0.0017</td>
#       <td id="T_cd4af_row3_col5" class="data row3 col5" >0.0018</td>
#     </tr>
#   </tbody>
# </table>

# %%
light_tuned = tune_model(lightdec, fold=2, n_iter=10, choose_better=True, return_tuner=True, return_train_score=True)
# Out:
# <style type="text/css">
# #T_b7431_row4_col0, #T_b7431_row4_col1, #T_b7431_row4_col2, #T_b7431_row4_col3, #T_b7431_row4_col4, #T_b7431_row4_col5, #T_b7431_row6_col0, #T_b7431_row6_col1, #T_b7431_row6_col2, #T_b7431_row6_col3, #T_b7431_row6_col4, #T_b7431_row6_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b7431">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7431_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b7431_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b7431_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b7431_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b7431_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b7431_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Split</th>
#       <th class="index_name level1" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7431_level0_row0" class="row_heading level0 row0" rowspan="2">CV-Train</th>
#       <th id="T_b7431_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_b7431_row0_col0" class="data row0 col0" >7.4736</td>
#       <td id="T_b7431_row0_col1" class="data row0 col1" >160.3087</td>
#       <td id="T_b7431_row0_col2" class="data row0 col2" >12.6613</td>
#       <td id="T_b7431_row0_col3" class="data row0 col3" >0.6894</td>
#       <td id="T_b7431_row0_col4" class="data row0 col4" >0.7900</td>
#       <td id="T_b7431_row0_col5" class="data row0 col5" >0.7884</td>
#     </tr>
#     <tr>
#       <th id="T_b7431_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_b7431_row1_col0" class="data row1 col0" >7.4942</td>
#       <td id="T_b7431_row1_col1" class="data row1 col1" >160.7977</td>
#       <td id="T_b7431_row1_col2" class="data row1 col2" >12.6806</td>
#       <td id="T_b7431_row1_col3" class="data row1 col3" >0.6890</td>
#       <td id="T_b7431_row1_col4" class="data row1 col4" >0.7895</td>
#       <td id="T_b7431_row1_col5" class="data row1 col5" >0.7908</td>
#     </tr>
#     <tr>
#       <th id="T_b7431_level0_row2" class="row_heading level0 row2" rowspan="2">CV-Val</th>
#       <th id="T_b7431_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_b7431_row2_col0" class="data row2 col0" >7.5945</td>
#       <td id="T_b7431_row2_col1" class="data row2 col1" >166.7490</td>
#       <td id="T_b7431_row2_col2" class="data row2 col2" >12.9131</td>
#       <td id="T_b7431_row2_col3" class="data row2 col3" >0.6775</td>
#       <td id="T_b7431_row2_col4" class="data row2 col4" >0.7976</td>
#       <td id="T_b7431_row2_col5" class="data row2 col5" >0.8017</td>
#     </tr>
#     <tr>
#       <th id="T_b7431_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_b7431_row3_col0" class="data row3 col0" >7.6006</td>
#       <td id="T_b7431_row3_col1" class="data row3 col1" >166.8867</td>
#       <td id="T_b7431_row3_col2" class="data row3 col2" >12.9185</td>
#       <td id="T_b7431_row3_col3" class="data row3 col3" >0.6767</td>
#       <td id="T_b7431_row3_col4" class="data row3 col4" >0.7955</td>
#       <td id="T_b7431_row3_col5" class="data row3 col5" >0.7989</td>
#     </tr>
#     <tr>
#       <th id="T_b7431_level0_row4" class="row_heading level0 row4" rowspan="2">CV-Train</th>
#       <th id="T_b7431_level1_row4" class="row_heading level1 row4" >Mean</th>
#       <td id="T_b7431_row4_col0" class="data row4 col0" >7.4839</td>
#       <td id="T_b7431_row4_col1" class="data row4 col1" >160.5532</td>
#       <td id="T_b7431_row4_col2" class="data row4 col2" >12.6710</td>
#       <td id="T_b7431_row4_col3" class="data row4 col3" >0.6892</td>
#       <td id="T_b7431_row4_col4" class="data row4 col4" >0.7897</td>
#       <td id="T_b7431_row4_col5" class="data row4 col5" >0.7896</td>
#     </tr>
#     <tr>
#       <th id="T_b7431_level1_row5" class="row_heading level1 row5" >Std</th>
#       <td id="T_b7431_row5_col0" class="data row5 col0" >0.0103</td>
#       <td id="T_b7431_row5_col1" class="data row5 col1" >0.2445</td>
#       <td id="T_b7431_row5_col2" class="data row5 col2" >0.0096</td>
#       <td id="T_b7431_row5_col3" class="data row5 col3" >0.0002</td>
#       <td id="T_b7431_row5_col4" class="data row5 col4" >0.0002</td>
#       <td id="T_b7431_row5_col5" class="data row5 col5" >0.0012</td>
#     </tr>
#     <tr>
#       <th id="T_b7431_level0_row6" class="row_heading level0 row6" rowspan="2">CV-Val</th>
#       <th id="T_b7431_level1_row6" class="row_heading level1 row6" >Mean</th>
#       <td id="T_b7431_row6_col0" class="data row6 col0" >7.5976</td>
#       <td id="T_b7431_row6_col1" class="data row6 col1" >166.8179</td>
#       <td id="T_b7431_row6_col2" class="data row6 col2" >12.9158</td>
#       <td id="T_b7431_row6_col3" class="data row6 col3" >0.6771</td>
#       <td id="T_b7431_row6_col4" class="data row6 col4" >0.7965</td>
#       <td id="T_b7431_row6_col5" class="data row6 col5" >0.8003</td>
#     </tr>
#     <tr>
#       <th id="T_b7431_level1_row7" class="row_heading level1 row7" >Std</th>
#       <td id="T_b7431_row7_col0" class="data row7 col0" >0.0031</td>
#       <td id="T_b7431_row7_col1" class="data row7 col1" >0.0688</td>
#       <td id="T_b7431_row7_col2" class="data row7 col2" >0.0027</td>
#       <td id="T_b7431_row7_col3" class="data row7 col3" >0.0004</td>
#       <td id="T_b7431_row7_col4" class="data row7 col4" >0.0011</td>
#       <td id="T_b7431_row7_col5" class="data row7 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_b7431_level0_row8" class="row_heading level0 row8" >Train</th>
#       <th id="T_b7431_level1_row8" class="row_heading level1 row8" >nan</th>
#       <td id="T_b7431_row8_col0" class="data row8 col0" >7.4685</td>
#       <td id="T_b7431_row8_col1" class="data row8 col1" >162.5342</td>
#       <td id="T_b7431_row8_col2" class="data row8 col2" >12.7489</td>
#       <td id="T_b7431_row8_col3" class="data row8 col3" >0.6854</td>
#       <td id="T_b7431_row8_col4" class="data row8 col4" >0.7882</td>
#       <td id="T_b7431_row8_col5" class="data row8 col5" >0.7875</td>
#     </tr>
#   </tbody>
# </table>

# %%
cols = X.drop(columns='arr_delay').columns
X_test = X_test[cols]

# %%
evaluate_model(light1)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
evaluate_model(light1)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
X_test = get_config('X_test')

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_387ca th {
#   text-align: left;
# }
# #T_387ca_row0_col0, #T_387ca_row0_col5, #T_387ca_row0_col6, #T_387ca_row1_col0, #T_387ca_row1_col1, #T_387ca_row1_col2, #T_387ca_row1_col3, #T_387ca_row1_col4, #T_387ca_row1_col5, #T_387ca_row2_col0, #T_387ca_row2_col1, #T_387ca_row2_col2, #T_387ca_row2_col3, #T_387ca_row2_col4, #T_387ca_row2_col5, #T_387ca_row2_col6, #T_387ca_row3_col0, #T_387ca_row3_col1, #T_387ca_row3_col2, #T_387ca_row3_col3, #T_387ca_row3_col4, #T_387ca_row3_col5, #T_387ca_row3_col6, #T_387ca_row4_col0, #T_387ca_row4_col1, #T_387ca_row4_col2, #T_387ca_row4_col3, #T_387ca_row4_col4, #T_387ca_row4_col5, #T_387ca_row4_col6, #T_387ca_row5_col0, #T_387ca_row5_col1, #T_387ca_row5_col2, #T_387ca_row5_col3, #T_387ca_row5_col4, #T_387ca_row5_col5, #T_387ca_row5_col6, #T_387ca_row6_col0, #T_387ca_row6_col1, #T_387ca_row6_col2, #T_387ca_row6_col3, #T_387ca_row6_col4, #T_387ca_row6_col6, #T_387ca_row7_col0, #T_387ca_row7_col1, #T_387ca_row7_col2, #T_387ca_row7_col3, #T_387ca_row7_col4, #T_387ca_row7_col5, #T_387ca_row7_col6, #T_387ca_row8_col0, #T_387ca_row8_col1, #T_387ca_row8_col2, #T_387ca_row8_col3, #T_387ca_row8_col4, #T_387ca_row8_col5, #T_387ca_row8_col6, #T_387ca_row9_col0, #T_387ca_row9_col1, #T_387ca_row9_col2, #T_387ca_row9_col3, #T_387ca_row9_col4, #T_387ca_row9_col5, #T_387ca_row9_col6, #T_387ca_row10_col0, #T_387ca_row10_col1, #T_387ca_row10_col2, #T_387ca_row10_col3, #T_387ca_row10_col4, #T_387ca_row10_col5, #T_387ca_row10_col6, #T_387ca_row11_col0, #T_387ca_row11_col1, #T_387ca_row11_col2, #T_387ca_row11_col3, #T_387ca_row11_col4, #T_387ca_row11_col5, #T_387ca_row11_col6, #T_387ca_row12_col0, #T_387ca_row12_col1, #T_387ca_row12_col2, #T_387ca_row12_col3, #T_387ca_row12_col4, #T_387ca_row12_col5, #T_387ca_row12_col6, #T_387ca_row13_col0, #T_387ca_row13_col1, #T_387ca_row13_col2, #T_387ca_row13_col3, #T_387ca_row13_col4, #T_387ca_row13_col5, #T_387ca_row13_col6, #T_387ca_row14_col0, #T_387ca_row14_col1, #T_387ca_row14_col2, #T_387ca_row14_col3, #T_387ca_row14_col4, #T_387ca_row14_col5, #T_387ca_row14_col6, #T_387ca_row15_col0, #T_387ca_row15_col1, #T_387ca_row15_col2, #T_387ca_row15_col3, #T_387ca_row15_col4, #T_387ca_row15_col5, #T_387ca_row15_col6, #T_387ca_row16_col0, #T_387ca_row16_col1, #T_387ca_row16_col2, #T_387ca_row16_col3, #T_387ca_row16_col4, #T_387ca_row16_col5, #T_387ca_row16_col6, #T_387ca_row17_col0, #T_387ca_row17_col1, #T_387ca_row17_col2, #T_387ca_row17_col3, #T_387ca_row17_col4, #T_387ca_row17_col5, #T_387ca_row17_col6 {
#   text-align: left;
# }
# #T_387ca_row0_col1, #T_387ca_row0_col2, #T_387ca_row0_col3, #T_387ca_row0_col4, #T_387ca_row1_col6, #T_387ca_row6_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_387ca_row0_col7, #T_387ca_row1_col7, #T_387ca_row2_col7, #T_387ca_row3_col7, #T_387ca_row4_col7, #T_387ca_row5_col7, #T_387ca_row6_col7, #T_387ca_row7_col7, #T_387ca_row8_col7, #T_387ca_row9_col7, #T_387ca_row10_col7, #T_387ca_row11_col7, #T_387ca_row12_col7, #T_387ca_row13_col7, #T_387ca_row14_col7, #T_387ca_row15_col7, #T_387ca_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_387ca_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_387ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_387ca_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_387ca_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_387ca_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_387ca_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_387ca_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_387ca_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_387ca_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_387ca_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_387ca_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_387ca_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_387ca_row0_col1" class="data row0 col1" >5.7143</td>
#       <td id="T_387ca_row0_col2" class="data row0 col2" >124.0744</td>
#       <td id="T_387ca_row0_col3" class="data row0 col3" >11.1389</td>
#       <td id="T_387ca_row0_col4" class="data row0 col4" >0.7328</td>
#       <td id="T_387ca_row0_col5" class="data row0 col5" >0.6944</td>
#       <td id="T_387ca_row0_col6" class="data row0 col6" >0.6380</td>
#       <td id="T_387ca_row0_col7" class="data row0 col7" >6.7275</td>
#     </tr>
#     <tr>
#       <th id="T_387ca_level0_row1" class="row_heading level0 row1" >gbr</th>
#       <td id="T_387ca_row1_col0" class="data row1 col0" >Gradient Boosting Regressor</td>
#       <td id="T_387ca_row1_col1" class="data row1 col1" >5.7566</td>
#       <td id="T_387ca_row1_col2" class="data row1 col2" >124.6120</td>
#       <td id="T_387ca_row1_col3" class="data row1 col3" >11.1630</td>
#       <td id="T_387ca_row1_col4" class="data row1 col4" >0.7317</td>
#       <td id="T_387ca_row1_col5" class="data row1 col5" >0.6949</td>
#       <td id="T_387ca_row1_col6" class="data row1 col6" >0.6343</td>
#       <td id="T_387ca_row1_col7" class="data row1 col7" >223.7525</td>
#     </tr>
#     <tr>
#       <th id="T_387ca_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_387ca_row2_col0" class="data row2 col0" >Ridge Regression</td>
#       <td id="T_387ca_row2_col1" class="data row2 col1" >6.5034</td>
#       <td id="T_387ca_row2_col2" class="data row2 col2" >130.7111</td>
#       <td id="T_387ca_row2_col3" class="data row2 col3" >11.4329</td>
#       <td id="T_387ca_row2_col4" class="data row2 col4" >0.7185</td>
#       <td id="T_387ca_row2_col5" class="data row2 col5" >0.7018</td>
#       <td id="T_387ca_row2_col6" class="data row2 col6" >0.7149</td>
#       <td id="T_387ca_row2_col7" class="data row2 col7" >0.3100</td>
#     </tr>
#     <tr>
#       <th id="T_387ca_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_387ca_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_387ca_row3_col1" class="data row3 col1" >6.5035</td>
#       <td id="T_387ca_row3_col2" class="data row3 col2" >130.7111</td>
#       <td id="T_387ca_row3_col3" class="data row3 col3" >11.4329</td>
#       <td id="T_387ca_row3_col4" class="data row3 col4" >0.7185</td>
#       <td id="T_387ca_row3_col5" class="data row3 col5" >0.7019</td>
#       <td id="T_387ca_row3_col6" class="data row3 col6" >0.7148</td>
#       <td id="T_387ca_row3_col7" class="data row3 col7" >3.0450</td>
#     </tr>
#     <tr>
#       <th id="T_387ca_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_387ca_row4_col0" class="data row4 col0" >Linear Regression</td>
#       <td id="T_387ca_row4_col1" class="data row4 col1" >6.5034</td>
#       <td id="T_387ca_row4_col2" class="data row4 col2" >130.7111</td>
#       <td id="T_387ca_row4_col3" class="data row4 col3" >11.4329</td>
#       <td id="T_387ca_row4_col4" class="data row4 col4" >0.7185</td>
#       <td id="T_387ca_row4_col5" class="data row4 col5" >0.7018</td>
#       <td id="T_387ca_row4_col6" class="data row4 col6" >0.7149</td>
#       <td id="T_387ca_row4_col7" class="data row4 col7" >1.0350</td>
#     </tr>
#     <tr>
#       <th id="T_387ca_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_387ca_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_387ca_row5_col1" class="data row5 col1" >6.5835</td>
#       <td id="T_387ca_row5_col2" class="data row5 col2" >134.6761</td>
#       <td id="T_387ca_row5_col3" class="data row5 col3" >11.6050</td>
#       <td id="T_387ca_row5_col4" class="data row5 col4" >0.7100</td>
#       <td id="T_387ca_row5_col5" class="data row5 col5" >0.6947</td>
#       <td id="T_387ca_row5_col6" class="data row5 col6" >0.7561</td>
#       <td id="T_387ca_row5_col7" class="data row5 col7" >0.3425</td>
#     </tr>
#     <tr>
#       <th id="T_38

# %%
light1 = finalize_model(light1)

# %%
y_pred = predict_model(light1, data=X_test)

# %%
import xgboost

# %%
xgboost = create_model('xgboost')
# Out:
# <style type="text/css">
# #T_fa2cb_row4_col0, #T_fa2cb_row4_col1, #T_fa2cb_row4_col2, #T_fa2cb_row4_col3, #T_fa2cb_row4_col4, #T_fa2cb_row4_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_fa2cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa2cb_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_fa2cb_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_fa2cb_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_fa2cb_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_fa2cb_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_fa2cb_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa2cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa2cb_row0_col0" class="data row0 col0" >7.5285</td>
#       <td id="T_fa2cb_row0_col1" class="data row0 col1" >166.8090</td>
#       <td id="T_fa2cb_row0_col2" class="data row0 col2" >12.9155</td>
#       <td id="T_fa2cb_row0_col3" class="data row0 col3" >0.6779</td>
#       <td id="T_fa2cb_row0_col4" class="data row0 col4" >0.7933</td>
#       <td id="T_fa2cb_row0_col5" class="data row0 col5" >0.8082</td>
#     </tr>
#     <tr>
#       <th id="T_fa2cb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa2cb_row1_col0" class="data row1 col0" >7.6416</td>
#       <td id="T_fa2cb_row1_col1" class="data row1 col1" >171.2454</td>
#       <td id="T_fa2cb_row1_col2" class="data row1 col2" >13.0861</td>
#       <td id="T_fa2cb_row1_col3" class="data row1 col3" >0.6682</td>
#       <td id="T_fa2cb_row1_col4" class="data row1 col4" >0.8001</td>
#       <td id="T_fa2cb_row1_col5" class="data row1 col5" >0.8173</td>
#     </tr>
#     <tr>
#       <th id="T_fa2cb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa2cb_row2_col0" class="data row2 col0" >7.5970</td>
#       <td id="T_fa2cb_row2_col1" class="data row2 col1" >170.8664</td>
#       <td id="T_fa2cb_row2_col2" class="data row2 col2" >13.0716</td>
#       <td id="T_fa2cb_row2_col3" class="data row2 col3" >0.6681</td>
#       <td id="T_fa2cb_row2_col4" class="data row2 col4" >0.7966</td>
#       <td id="T_fa2cb_row2_col5" class="data row2 col5" >0.8132</td>
#     </tr>
#     <tr>
#       <th id="T_fa2cb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fa2cb_row3_col0" class="data row3 col0" >7.5553</td>
#       <td id="T_fa2cb_row3_col1" class="data row3 col1" >167.3069</td>
#       <td id="T_fa2cb_row3_col2" class="data row3 col2" >12.9347</td>
#       <td id="T_fa2cb_row3_col3" class="data row3 col3" >0.6767</td>
#       <td id="T_fa2cb_row3_col4" class="data row3 col4" >0.7958</td>
#       <td id="T_fa2cb_row3_col5" class="data row3 col5" >0.8074</td>
#     </tr>
#     <tr>
#       <th id="T_fa2cb_level0_row4" class="row_heading level0 row4" >Mean</th>
#       <td id="T_fa2cb_row4_col0" class="data row4 col0" >7.5806</td>
#       <td id="T_fa2cb_row4_col1" class="data row4 col1" >169.0569</td>
#       <td id="T_fa2cb_row4_col2" class="data row4 col2" >13.0020</td>
#       <td id="T_fa2cb_row4_col3" class="data row4 col3" >0.6727</td>
#       <td id="T_fa2cb_row4_col4" class="data row4 col4" >0.7965</td>
#       <td id="T_fa2cb_row4_col5" class="data row4 col5" >0.8115</td>
#     </tr>
#     <tr>
#       <th id="T_fa2cb_level0_row5" class="row_heading level0 row5" >Std</th>
#       <td id="T_fa2cb_row5_col0" class="data row5 col0" >0.0429</td>
#       <td id="T_fa2cb_row5_col1" class="data row5 col1" >2.0112</td>
#       <td id="T_fa2cb_row5_col2" class="data row5 col2" >0.0773</td>
#       <td id="T_fa2cb_row5_col3" class="data row5 col3" >0.0046</td>
#       <td id="T_fa2cb_row5_col4" class="data row5 col4" >0.0024</td>
#       <td id="T_fa2cb_row5_col5" class="data row5 col5" >0.0040</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(X.columns, X_test.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 print(X.columns, X_test.columns)
#
# NameError: name 'X' is not defined

# %%
big = pd.read_csv('EDA_and_preprocessing/G_PSQL_data/new flights.txt')

# %%
print(dec.isnull().sum(), dec.nunique())
# Out:
# fl_date                            0
# op_unique_carrier                  0
# tail_num                           0
# origin_airport_id                  0
# dest_airport_id                    0
# crs_dep_time                       0
# dep_time                           0
# dep_delay                          0
# taxi_out                           0
# taxi_in                            0
# crs_arr_time                       0
# arr_time                           0
# arr_delay                          0
# crs_elapsed_time                   0
# actual_elapsed_time                0
# dep_hour                           0
# arr_hour                           0
# weekday                            0
# month_day                          0
# late_binary                        0
# reduced_delay_flight               0
# airport_weekly_hourly_arr          0
# airport_weekly_hourly_dep          0
# airport_arr_hourly_late_percent    0
# airport_dep_hourly_late_percent    0
# airport_taxi_in                    0
# airport_taxi_out                   0
# taxi_total                         0
# tail_arr                           0
# tail_dep                           0
# tail_taxi                          0
# tail_precent_late                  0
# tail_percent_reduce_delay          0
# carrier_arr                        0
# carrier_dep                        0
# carrier_percent_late               0
# carrier_taxi_total                 0
# percent_carrier_delay_reduced      0
# weekday_arr                        0
# weekday_dep                        0
# weekday_taxi                       0
# weekly_percent_late                0
# weekly_reduced_delay               0
# route_arr_mean                     0
# route_dep_mean                     0
# carrier_route_arr_mean             0
# carrier_route_dep_mean             0
# carrier_route_air_actual           0
# carrier_route_air_pred             0
# tail_route_arr_mean                0
# tail_route_dep_mean                0
# tail_route_air_ratio               0
# dtype: int64 fl_date                               31
# op_unique_carrier                     25
# tail_num                            5515
# origin_airport_id                    363
# dest_airport_id                      363
# crs_dep_time                        1261
# dep_time                            1432
# dep_delay                            191
# taxi_out                             140
# taxi_in                              115
# crs_arr_time                        1394
# arr_time                            1440
# arr_delay                            149
# crs_elapsed_time                     422
# actual_elapsed_time                  483
# dep_hour                              24
# arr_hour                              24
# weekday                                7
# month_day                             31
# late_binary                            2
# reduced_delay_flight                   2
# airport_weekly_hourly_arr           8123
# airport_weekly_hourly_dep           7658
# airport_arr_hourly_late_percent     1735
# airport_dep_hourly_late_percent     1685
# airport_taxi_in                      361
# airport_taxi_out                     363
# taxi_total                           147
# tail_arr                            5201
# tail_dep                            5183
# tail_taxi                           5106
# tail_precent_late                   2376
# tail_percent_reduce_delay           2242
# carrier_arr                           25
# carrier_dep                           25
# carrier_percent_late                  25
# carrier_taxi_total                    25
# percent_carrier_delay_reduced         25
# weekday_arr                            7
# weekday_dep                            7
# weekday_taxi                           7
# weekly_percent_late                    7
# weekly_reduced_delay                   7
# route_arr_mean                      5186
# route_dep_mean                      5019
# carrier_route_arr_mean              8203
# carrier_route_dep_mean              7733
# carrier_route_air_actual           10087
# carrier_route_air_pred              9265
# tail_route_arr_mean                 2230
# tail_route_dep_mean                 1993
# tail_route_air_ratio               41087
# dtype: int64

# %%
print(test.isnull().sum(), test.nunique())
# Out:
# year                                    0
# month                                   0
# day                                     0
# op_unique_carrier                       0
# tail_num                              124
# origin_airport_id                       0
# dest_airport_id                         0
# crs_dep_time                            0
# crs_arr_time                            0
# crs_elapsed_time                        0
# fl_date                                 0
# dep_hour                               17
# arr_hour                              514
# weekday                                 0
# month_day                               0
# tail_arr                              538
# tail_dep                              538
# tail_taxi                             538
# tail_precent_late                     538
# tail_percent_reduce_delay             538
# carrier_arr                             0
# carrier_dep                             0
# carrier_percent_late                    0
# carrier_taxi_total                      0
# percent_carrier_delay_reduced           0
# weekday_arr                             0
# weekday_dep                             0
# weekday_taxi                            0
# weekly_percent_late                     0
# weekly_reduced_delay                    0
# arr_hourly_arr                        514
# arr_hourly_dep                        514
# arr_hour_taxi                         514
# arr_hourly_percent_late               514
# arr_hourly_percent_reduced_delay      514
# dep_hourly_arr                         17
# dep_hourly_dep                         17
# dep_hourly_taxi                        17
# dep_hourly_percent_late                17
# dep_hourly_percent_reduced             17
# route_arr_mean                        195
# route_dep_mean                        195
# carrier_route_arr_mean                724
# carrier_route_dep_mean                724
# carrier_route_air_percent             724
# tail_route_arr_mean                 77083
# tail_route_dep_mean                 77083
# tail_route_air_ratio                77083
# airport_weekly_hourly_arr            1007
# airport_weekly_hourly_dep             434
# airport_arr_hourly_late_percent       669
# airport_dep_hourly_late_percent       191
# airport_taxi_in                         0
# airport_taxi_out                        0
# dtype: int64 year                                    1
# month                                   1
# day                                     7
# op_unique_carrier                      25
# tail_num                             5556
# origin_airport_id                     363
# dest_airport_id                       363
# crs_dep_time                         1229
# crs_arr_time                         1311
# crs_elapsed_time                      454
# fl_date                                 7
# dep_hour                               24
# arr_hour                               24
# weekday                                 7
# month_day                               7
# tail_arr                             5201
# tail_dep                             5183
# tail_taxi                            5106
# tail_precent_late                    2376
# tail_percent_reduce_delay            2242
# carrier_arr                            25
# carrier_dep                            25
# carrier_percent_late                   25
# carrier_taxi_total                     25
# percent_carrier_delay_reduced          25
# weekday_arr                             7
# weekday_dep                             7
# weekday_taxi                            7
# weekly_percent_late                     7
# weekly_reduced_delay                    7
# arr_hourly_arr                         24
# arr_hourly_dep                         24
# arr_hour_taxi                          24
# arr_hourly_percent_late                24
# arr_hourly_percent_reduced_delay       24
# dep_hourly_arr                         24
# dep_hourly_dep                         24
# dep_hourly_taxi                        24
# dep_hourly_percent_late                24
# dep_hourly_percent_reduced             24
# route_arr_mean                       5163
# route_dep_mean                       5004
# carrier_route_arr_mean               7989
# carrier_route_dep_mean               7554
# carrier_route_air_percent           10623
# tail_route_arr_mean                  1840
# tail_route_dep_mean                  1640
# tail_route_air_ratio                19678
# airport_weekly_hourly_arr            8044
# airport_weekly_hourly_dep            7589
# airport_arr_hourly_late_percent      1731
# airport_dep_hourly_late_percent      1665
# airport_taxi_in                       361
# airport_taxi_out                      363
# dtype: int64

# %%
dec = pd.read_csv('EDA_and_preprocessing/G_PSQL_data/december_flights.txt')

# %%
set(X.drop(columns='arr_delay').columns) == set(X_test.columns)
# Out:
# True

# %%
save_model(light1, 'lgbm_all_december')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='arr_delay',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strate...
#                   LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None, random_state=5418,
#                                 reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                                 subsample=1.0, subsample_for_bin=200000,
#                                 subsample_freq=0)]],
#           verbose=False),
#  'lgbm_all_december.pkl')

# %%
set(test['tail_num']) - set(dec['tail_num'])
# Out:
# {'N106NN',
#  'N11113',
#  'N12010',
#  'N166PQ',
#  'N16713',
#  'N18243',
#  'N2027J',
#  'N227JQ',
#  'N2748U',
#  'N289MW',
#  'N36915',
#  'N38443',
#  'N38950',
#  'N391DN',
#  'N426AW',
#  'N504DN',
#  'N511DN',
#  'N554GJ',
#  'N582CA',
#  'N618UX',
#  'N619UX',
#  'N668UA',
#  'N670UA',
#  'N672UA',
#  'N677UA',
#  'N702DN',
#  'N727TW',
#  'N753AN',
#  'N78017',
#  'N7821L',
#  'N7849A',
#  'N7866A',
#  'N7867A',
#  'N786UA',
#  'N798UA',
#  'N801UA',
#  'N804HC',
#  'N804NW',
#  'N839MH',
#  'N8932C',
#  'N8968E',
#  nan}

# %%
air_traffic = pd.read_csv('EDA_and_preprocessing/G_PSQL_data/air_traffic_binned.csv')
airline_delay = pd.read_csv('EDA_and_preprocessing/G_PSQL_data/airline_delay_rating.csv')
weather_test = pd.read_csv('EDA_and_preprocessing/G_PSQL_data/weather_test.csv')
weather_train = pd.read_csv('EDA_and_preprocessing/G_PSQL_data/weather_train.csv')
